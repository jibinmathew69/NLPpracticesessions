# %%
def load_data():
    reviewsFile = open('reviews.txt','r')
    reviews = list(map(lambda x:x[:-1],reviewsFile.readlines()))
    reviewsFile.close()

    labelsFile = open('labels.txt','r')
    labels = list(map(lambda x:x[:-1],labelsFile.readlines()))
    labelsFile.close()
    
    return reviews,labels

# %%
reviews,labels = load_data()

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer("\w+\'?\w+|\w+")

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
from spacy.lang.en.stop_words import STOP_WORDS
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)

# %%
exceptionStopWords = {
    'again',
    'against',
    'ain',
    'almost',
    'among',
    'amongst',
    'amount',
    'anyhow',
    'anyway',
    'aren',
    "aren't",
    'below',
    'bottom',
    'but',
    'cannot',
    'couldn',
    "couldn't",
    'didn',
    "didn't",
    'doesn',
    "doesn't",
    'don',
    "don't",
    'done',
    'down',
    'except',
    'few',
    'hadn',
    "hadn't",
    'hasn',
    "hasn't",
    'haven',
    "haven't",
    'however',
    'isn',
    "isn't",
    'least',
    'mightn',
    "mightn't",
    'move',
    'much',
    'must',
    'mustn',
    "mustn't",
    'needn',
    "needn't",
    'neither',
    'never',
    'nevertheless',
    'no',
    'nobody',
    'none',
    'noone',
    'nor',
    'not',
    'nothing',
    'should',
    "should've",
    'shouldn',
    "shouldn't",
    'too',
    'top',
    'up',
    'wasn',
    "wasn't",
    'well',
    'weren',
    "weren't",
    'won',
    "won't",
    'wouldn',
    "wouldn't",
}

# %%
stop_words = set(stop_words).union(STOP_WORDS)

# %%
final_stop_words = stop_words-exceptionStopWords

# %%
import spacy
nlp = spacy.load("en",disable=['parser', 'tagger', 'ner'])

# %%
def make_token(review):
    return tokenizer.tokenize(str(review))

# %%
def remove_stopwords(review):
    return [token for token in review if token not in final_stop_words]

# %%
def lemmatization(review):
    lemma_result = []
    
    for words in review:
        doc = nlp(words)
        for token in doc:
            lemma_result.append(token.lemma_)
    return lemma_result

# %%
def pipeline(review):
    review = make_token(review)
    review = remove_stopwords(review)
    return lemmatization(review)

# %%
# %%time
reviews = list(map(lambda review: pipeline(review),reviews))
# Out:
# CPU times: user 2min 20s, sys: 124 ms, total: 2min 20s
# Wall time: 2min 20s

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(reviews,size=100, window=5, min_count=5, workers=4)

# %%
reviews[:5]
# Out:
# [['bromwell',
#   'high',
#   'cartoon',
#   'comedy',
#   'run',
#   'time',
#   'program',
#   'school',
#   'life',
#   'teacher',
#   'year',
#   'teach',
#   'profession',
#   'lead',
#   'believe',
#   'bromwell',
#   'high',
#   'satire',
#   'much',
#   'close',
#   'reality',
#   'teacher',
#   'scramble',
#   'survive',
#   'financially',
#   'insightful',
#   'student',
#   'right',
#   'pathetic',
#   'teacher',
#   'pomp',
#   'pettiness',
#   'situation',
#   'remind',
#   'school',
#   'know',
#   'student',
#   'see',
#   'episode',
#   'student',
#   'repeatedly',
#   'try',
#   'burn',
#   'down',
#   'school',
#   'immediately',
#   'recall',
#   'high',
#   'classic',
#   'line',
#   'inspector',
#   'sack',
#   'teacher',
#   'student',
#   'welcome',
#   'bromwell',
#   'high',
#   'expect',
#   'adult',
#   'age',
#   'think',
#   'bromwell',
#   'high',
#   'far',
#   'fetch',
#   'pity',
#   'isn'],
#  ['story',
#   'man',
#   'unnatural',
#   'feeling',
#   'pig',
#   'start',
#   'open',
#   'scene',
#   'terrific',
#   'example',
#   'absurd',
#   'comedy',
#   'formal',
#   'orchestra',
#   'audience',
#   'turn',
#   'insane',
#   'violent',
#   'mob',
#   'crazy',
#   'chantings',
#   'singer',
#   'unfortunately',
#   'stay',
#   'absurd',
#   'time',
#   'no',
#   'general',
#   'narrative',
#   'eventually',
#   'make',
#   'too',
#   'putt',
#   'era',
#   'should',
#   'turn',
#   'cryptic',
#   'dialogue',
#   'shakespeare',
#   'easy',
#   'grader',
#   'technical',
#   'level',
#   'well',
#   'think',
#   'good',
#   'cinematography',
#   'future',
#   'great',
#   'vilmos',
#   'zsigmond',
#   'future',
#   'star',
#   'sally',
#   'kirkland',
#   'frederic',
#   'forrest',
#   'see',
#   'briefly'],
#  ['homelessness',
#   'houselessness',
#   'george',
#   'carlin',
#   'state',
#   'issue',
#   'year',
#   'but',
#   'never',
#   'plan',
#   'help',
#   'street',
#   'consider',
#   'human',
#   'go',
#   'school',
#   'work',
#   'vote',
#   'matt',
#   'people',
#   'think',
#   'homeless',
#   'lose',
#   'because',
#   'worry',
#   'thing',
#   'racism',
#   'war',
#   'iraq',
#   'pressure',
#   'kid',
#   'succeed',
#   'technology',
#   'election',
#   'inflation',
#   'worry',
#   'end',
#   'up',
#   'street',
#   'br',
#   'br',
#   'but',
#   'give',
#   'bet',
#   'live',
#   'street',
#   'month',
#   'luxury',
#   'home',
#   'entertainment',
#   'set',
#   'bathroom',
#   'picture',
#   'wall',
#   'computer',
#   'treasure',
#   'like',
#   'homeless',
#   'goddard',
#   'bolt',
#   'lesson',
#   'br',
#   'br',
#   'mel',
#   'brook',
#   'direct',
#   'star',
#   'bolt',
#   'play',
#   'rich',
#   'man',
#   'world',
#   'decide',
#   'bet',
#   'sissy',
#   'rival',
#   'jeffery',
#   'tambor',
#   'live',
#   'street',
#   'thirty',
#   'day',
#   'luxury',
#   'bolt',
#   'succeed',
#   'want',
#   'future',
#   'project',
#   'make',
#   'building',
#   'bet',
#   'bolt',
#   'throw',
#   'street',
#   'bracelet',
#   'leg',
#   'monitor',
#   'move',
#   'step',
#   'sidewalk',
#   'give',
#   'nickname',
#   'pepto',
#   'vagrant',
#   'write',
#   'forehead',
#   'bolt',
#   'meet',
#   'character',
#   'include',
#   'woman',
#   'molly',
#   'lesley',
#   'ann',
#   'warren',
#   'ex',
#   'dancer',
#   'get',
#   'divorce',
#   'lose',
#   'home',
#   'pal',
#   'sailor',
#   'howard',
#   'morris',
#   'fume',
#   'teddy',
#   'wilson',
#   'street',
#   'survivor',
#   'bolt',
#   'isn',
#   'not',
#   'reach',
#   'mutual',
#   'agreement',
#   'like',
#   'rich',
#   'fight',
#   'flight',
#   'kill',
#   'kill',
#   'br',
#   'br',
#   'love',
#   'connection',
#   'molly',
#   'bolt',
#   'wasn',
#   'necessary',
#   'plot',
#   'find',
#   'life',
#   'stink',
#   'mel',
#   'brook',
#   'observant',
#   'film',
#   'prior',
#   'comedy',
#   'show',
#   'tender',
#   'compare',
#   'slapstick',
#   'work',
#   'blaze',
#   'saddle',
#   'young',
#   'frankenstein',
#   'spaceballs',
#   'matt',
#   'like',
#   'valuable',
#   'lose',
#   'day',
#   'hand',
#   'make',
#   'stupid',
#   'bet',
#   'like',
#   'rich',
#   'people',
#   'don',
#   'know',
#   'money',
#   'maybe',
#   'should',
#   'homeless',
#   'instead',
#   'like',
#   'monopoly',
#   'money',
#   'br',
#   'br',
#   'maybe',
#   'film',
#   'inspire',
#   'help'],
#  ['airport',
#   'start',
#   'brand',
#   'new',
#   'luxury',
#   'plane',
#   'load',
#   'up',
#   'valuable',
#   'painting',
#   'belong',
#   'rich',
#   'businessman',
#   'philip',
#   'stevens',
#   'james',
#   'stewart',
#   'fly',
#   'bunch',
#   'vip',
#   'estate',
#   'preparation',
#   'open',
#   'public',
#   'museum',
#   'board',
#   'stevens',
#   'daughter',
#   'julie',
#   'kathleen',
#   'quinlan',
#   'son',
#   'luxury',
#   'jetliner',
#   'take',
#   'plan',
#   'but',
#   'mid',
#   'air',
#   'plane',
#   'hello',
#   'jack',
#   'co',
#   'pilot',
#   'chamber',
#   'robert',
#   'foxworth',
#   'accomplice',
#   'banker',
#   'monte',
#   'markham',
#   'wilson',
#   'michael',
#   'pataki',
#   'knock',
#   'passenger',
#   'crow',
#   'sleep',
#   'gas',
#   'plan',
#   'steal',
#   'valuable',
#   'cargo',
#   'land',
#   'disused',
#   'plane',
#   'strip',
#   'isolate',
#   'island',
#   'but',
#   'make',
#   'descent',
#   'chamber',
#   'almost',
#   'hit',
#   'oil',
#   'rig',
#   'ocean',
#   'lose',
#   'control',
#   'plane',
#   'send',
#   'crash',
#   'sea',
#   'sink',
#   'bottom',
#   'right',
#   'bang',
#   'middle',
#   'bermuda',
#   'triangle',
#   'air',
#   'short',
#   'supply',
#   'water',
#   'leak',
#   'fly',
#   'mile',
#   'course',
#   'problem',
#   'mount',
#   'survivor',
#   'await',
#   'help',
#   'time',
#   'fast',
#   'run',
#   'br',
#   'br',
#   'know',
#   'slightly',
#   'different',
#   'tile',
#   'airport',
#   '2',
#   'sequel',
#   'smash',
#   'hit',
#   'disaster',
#   'thriller',
#   'airport',
#   'direct',
#   'jerry',
#   'jameson',
#   'again',
#   'like',
#   'predecessor',
#   'airport',
#   'sort',
#   'forget',
#   'classic',
#   'entertain',
#   'not',
#   'necessarily',
#   'right',
#   'reason',
#   'airport',
#   'film',
#   'see',
#   'far',
#   'actually',
#   'like',
#   'well',
#   'favourite',
#   'plot',
#   'nice',
#   'mid',
#   'air',
#   'hello',
#   'jack',
#   'crash',
#   'didn',
#   'oil',
#   'rig',
#   'sink',
#   'maybe',
#   'maker',
#   'try',
#   'cross',
#   'original',
#   'airport',
#   'popular',
#   'disaster',
#   'flick',
#   'period',
#   'poseidon',
#   'adventure',
#   'submerge',
#   'stay',
#   'end',
#   'stark',
#   'dilemma',
#   'face',
#   'trap',
#   'inside',
#   'suffocate',
#   'air',
#   'run',
#   'drown',
#   'flood',
#   'door',
#   'open',
#   'decent',
#   'idea',
#   'great',
#   'little',
#   'disaster',
#   'flick',
#   'but',
#   'bad',
#   'unsympathetic',
#   'character',
#   'dull',
#   'dialogue',
#   'lethargic',
#   'set',
#   'piece',
#   'real',
#   'lack',
#   'danger',
#   'suspense',
#   'tension',
#   'mean',
#   'miss',
#   'opportunity',
#   'sluggish',
#   'plot',
#   'keep',
#   'entertain',
#   'odd',
#   'minute',
#   'not',
#   'much',
#   'happen',
#   'plane',
#   'sink',
#   'not',
#   'much',
#   'urgency',
#   'think',
#   'should',
#   'navy',
#   'involve',
#   'thing',
#   'don',
#   'pick',
#   'up',
#   'much',
#   'few',
#   'shot',
#   'huge',
#   'ship',
#   'helicopter',
#   'fly',
#   'but',
#   'lack',
#   'george',
#   'kennedy',
#   'jinx',
#   'airline',
#   'worker',
#   'joe',
#   'patroni',
#   'but',
#   'get',
#   'couple',
#   'scene',
#   'barely',
#   'say',
#   'prefer',
#   'look',
#   'worry',
#   'background',
#   'br',
#   'br',
#   'home',
#   'video',
#   'theatrical',
#   'version',
#   'airport',
#   'run',
#   'minute',
#   'tv',
#   'version',
#   'add',
#   'extra',
#   'hour',
#   'footage',
#   'include',
#   'new',
#   'open',
#   'credit',
#   'sequence',
#   'scene',
#   'george',
#   'kennedy',
#   'patroni',
#   'flashback',
#   'flesh',
#   'character',
#   'long',
#   'rescue',
#   'scene',
#   'discovery',
#   'couple',
#   'dead',
#   'body',
#   'include',
#   'navigator',
#   'like',
#   'extra',
#   'footage',
#   'not',
#   'sure',
#   'sit',
#   'near',
#   'hour',
#   'cut',
#   'airport',
#   'expect',
#   'film',
#   'date',
#   'badly',
#   'horrible',
#   'fashion',
#   'interior',
#   'design',
#   'choice',
#   'no',
#   'toy',
#   'plane',
#   'model',
#   'effect',
#   'aren',
#   'great',
#   'airport',
#   'sequel',
#   'take',
#   'pride',
#   'place',
#   'razzie',
#   'award',
#   'hall',
#   'shame',
#   'think',
#   'lot',
#   'wrong',
#   'film',
#   'reckon',
#   'little',
#   'harsh',
#   'action',
#   'scene',
#   'little',
#   'dull',
#   'unfortunately',
#   'pace',
#   'slow',
#   'not',
#   'much',
#   'excitement',
#   'tension',
#   'generate',
#   'shame',
#   'reckon',
#   'pretty',
#   'good',
#   'film',
#   'properly',
#   'br',
#   'br',
#   'production',
#   'value',
#   'alright',
#   'nothing',
#   'spectacular',
#   'act',
#   'isn',
#   'great',
#   'time',
#   'oscar',
#   'winner',
#   'jack',
#   'lemmon',
#   'say',
#   'mistake',
#   'star',
#   'time',
#   'oscar',
#   'winner',
#   'james',
#   'stewart',
#   'look',
#   'old',
#   'frail',
#   'time',
#   'oscar',
#   'winner',
#   'lee',
#   'grant',
#   'look',
#   'drink',
#   'sir',
#   'christopher',
#   'lee',
#   'give',
#   'little',
#   'plenty',
#   'familiar',
#   'face',
#   'look',
#   'too',
#   'br',
#   'br',
#   'airport',
#   'disaster',
#   'orientate',
#   'airport',
#   'film',
#   'far',
#   'like',
#   'idea',
#   'bite',
#   'silly',
#   'production',
#   'bland',
#   'direction',
#   'doesn',
#   'help',
#   'film',
#   'sink',
#   'plane',
#   'shouldn',
#   'bore',
#   'lethargic',
#   'follow',
#   'concorde',
#   'airport'],
#  ['brilliant',
#   'act',
#   'lesley',
#   'ann',
#   'warren',
#   'well',
#   'dramatic',
#   'hobo',
#   'lady',
#   'see',
#   'love',
#   'scene',
#   'clothe',
#   'warehouse',
#   '2',
#   'none',
#   'corn',
#   'face',
#   'classic',
#   'good',
#   'blaze',
#   'saddle',
#   'lawyer',
#   'superb',
#   'accuse',
#   'turncoat',
#   'sell',
#   'boss',
#   'dishonest',
#   'lawyer',
#   'pepto',
#   'bolt',
#   'shrug',
#   'indifferently',
#   'lawyer',
#   'say',
#   'funny',
#   'word',
#   'jeffrey',
#   'tambor',
#   'favorite',
#   'late',
#   'larry',
#   'sander',
#   'fantastic',
#   'too',
#   'mad',
#   'millionaire',
#   'want',
#   'crush',
#   'ghetto',
#   'character',
#   'malevolent',
#   'usual',
#   'hospital',
#   'scene',
#   'scene',
#   'homeless',
#   'invade',
#   'demolition',
#   'site',
#   'time',
#   'classic',
#   'look',
#   'leg',
#   'scene',
#   'big',
#   'digger',
#   'fight',
#   'bleed',
#   'movie',
#   'get',
#   'well',
#   'time']]

# %%
model.similar_by_word(word="good", topn=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('decent', 0.7002853751182556),
#  ('alright', 0.6784442067146301),
#  ('great', 0.6605183482170105),
#  ('darn', 0.6370904445648193),
#  ('nice', 0.6335242986679077)]

# %%
model.similar_by_word(word="bad", topn=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('terrible', 0.7277318835258484),
#  ('horrible', 0.7230232954025269),
#  ('awful', 0.7105058431625366),
#  ('lousy', 0.681010365486145),
#  ('suck', 0.6726512908935547)]

# %%
model.similar_by_word(word="be", topn=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('would', 0.917330265045166),
#  ('-PRON-', 0.8382889628410339),
#  ('have', 0.832093358039856),
#  ('eventy', 0.789171576499939),
#  ('s', 0.76078861951828)]
