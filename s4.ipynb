# %%
def load_data():
    reviewsFile = open('reviews.txt','r')
    reviews = list(map(lambda x:x[:-1],reviewsFile.readlines()))
    reviewsFile.close()

    labelsFile = open('labels.txt','r')
    labels = list(map(lambda x:x[:-1],labelsFile.readlines()))
    labelsFile.close()
    
    return reviews,labels

# %%
reviews,labels = load_data()

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer("\w+\'?\w+|\w+")

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
exceptionStopWords = {
    'again',
    'against',
    'ain',
    'almost',
    'among',
    'amongst',
    'amount',
    'anyhow',
    'anyway',
    'aren',
    "aren't",
    'below',
    'bottom',
    'but',
    'cannot',
    'couldn',
    "couldn't",
    'didn',
    "didn't",
    'doesn',
    "doesn't",
    'don',
    "don't",
    'done',
    'down',
    'except',
    'few',
    'hadn',
    "hadn't",
    'hasn',
    "hasn't",
    'haven',
    "haven't",
    'however',
    'isn',
    "isn't",
    'least',
    'mightn',
    "mightn't",
    'move',
    'much',
    'must',
    'mustn',
    "mustn't",
    'needn',
    "needn't",
    'neither',
    'never',
    'nevertheless',
    'no',
    'nobody',
    'none',
    'noone',
    'nor',
    'not',
    'nothing',
    'should',
    "should've",
    'shouldn',
    "shouldn't",
    'too',
    'top',
    'up',
    'wasn',
    "wasn't",
    'well',
    'weren',
    "weren't",
    'won',
    "won't",
    'wouldn',
    "wouldn't",
}

# %%
stop_words = set(stop_words).union(STOP_WORDS)

# %%
final_stop_words = stop_words-exceptionStopWords

# %%
import spacy
nlp = spacy.load("en",disable=['parser', 'tagger', 'ner'])

# %%
def make_token(review):
    return tokenizer.tokenize(str(review))

# %%
def remove_stopwords(review):
    return [token for token in review if token not in final_stop_words]

# %%
def lemmatization(review):
    lemma_result = []
    
    for words in review:
        doc = nlp(words)
        for token in doc:
            lemma_result.append(token.lemma_)
    return lemma_result

# %%
def pipeline(review):
    review = make_token(review)
    review = remove_stopwords(review)
    return lemmatization(review)

# %%
# %%time
reviews = list(map(lambda review: pipeline(review),reviews))
# Out:
# CPU times: user 34.5 s, sys: 102 ms, total: 34.6 s
# Wall time: 34.6 s

# %%
from gensim.models import Word2Vec

# %%
emb_model = Word2Vec(reviews,size=100, min_count=3, window=5, workers=6)

# %%
reviews[:5]
# Out:
# [['bromwell',
#   'high',
#   'cartoon',
#   'comedy',
#   'run',
#   'time',
#   'program',
#   'school',
#   'life',
#   'teacher',
#   'year',
#   'teach',
#   'profession',
#   'lead',
#   'believe',
#   'bromwell',
#   'high',
#   'satire',
#   'much',
#   'close',
#   'reality',
#   'teacher',
#   'scramble',
#   'survive',
#   'financially',
#   'insightful',
#   'student',
#   'right',
#   'pathetic',
#   'teacher',
#   'pomp',
#   'pettiness',
#   'situation',
#   'remind',
#   'school',
#   'know',
#   'student',
#   'see',
#   'episode',
#   'student',
#   'repeatedly',
#   'try',
#   'burn',
#   'down',
#   'school',
#   'immediately',
#   'recall',
#   'high',
#   'classic',
#   'line',
#   'inspector',
#   'sack',
#   'teacher',
#   'student',
#   'welcome',
#   'bromwell',
#   'high',
#   'expect',
#   'adult',
#   'age',
#   'think',
#   'bromwell',
#   'high',
#   'far',
#   'fetch',
#   'pity',
#   'isn'],
#  ['story',
#   'man',
#   'unnatural',
#   'feeling',
#   'pig',
#   'start',
#   'open',
#   'scene',
#   'terrific',
#   'example',
#   'absurd',
#   'comedy',
#   'formal',
#   'orchestra',
#   'audience',
#   'turn',
#   'insane',
#   'violent',
#   'mob',
#   'crazy',
#   'chantings',
#   'singer',
#   'unfortunately',
#   'stay',
#   'absurd',
#   'time',
#   'no',
#   'general',
#   'narrative',
#   'eventually',
#   'make',
#   'too',
#   'putt',
#   'era',
#   'should',
#   'turn',
#   'cryptic',
#   'dialogue',
#   'shakespeare',
#   'easy',
#   'grader',
#   'technical',
#   'level',
#   'well',
#   'think',
#   'good',
#   'cinematography',
#   'future',
#   'great',
#   'vilmos',
#   'zsigmond',
#   'future',
#   'star',
#   'sally',
#   'kirkland',
#   'frederic',
#   'forrest',
#   'see',
#   'briefly'],
#  ['homelessness',
#   'houselessness',
#   'george',
#   'carlin',
#   'state',
#   'issue',
#   'year',
#   'but',
#   'never',
#   'plan',
#   'help',
#   'street',
#   'consider',
#   'human',
#   'go',
#   'school',
#   'work',
#   'vote',
#   'matt',
#   'people',
#   'think',
#   'homeless',
#   'lose',
#   'because',
#   'worry',
#   'thing',
#   'racism',
#   'war',
#   'iraq',
#   'pressure',
#   'kid',
#   'succeed',
#   'technology',
#   'election',
#   'inflation',
#   'worry',
#   'end',
#   'up',
#   'street',
#   'br',
#   'br',
#   'but',
#   'give',
#   'bet',
#   'live',
#   'street',
#   'month',
#   'luxury',
#   'home',
#   'entertainment',
#   'set',
#   'bathroom',
#   'picture',
#   'wall',
#   'computer',
#   'treasure',
#   'like',
#   'homeless',
#   'goddard',
#   'bolt',
#   'lesson',
#   'br',
#   'br',
#   'mel',
#   'brook',
#   'direct',
#   'star',
#   'bolt',
#   'play',
#   'rich',
#   'man',
#   'world',
#   'decide',
#   'bet',
#   'sissy',
#   'rival',
#   'jeffery',
#   'tambor',
#   'live',
#   'street',
#   'thirty',
#   'day',
#   'luxury',
#   'bolt',
#   'succeed',
#   'want',
#   'future',
#   'project',
#   'make',
#   'building',
#   'bet',
#   'bolt',
#   'throw',
#   'street',
#   'bracelet',
#   'leg',
#   'monitor',
#   'move',
#   'step',
#   'sidewalk',
#   'give',
#   'nickname',
#   'pepto',
#   'vagrant',
#   'write',
#   'forehead',
#   'bolt',
#   'meet',
#   'character',
#   'include',
#   'woman',
#   'molly',
#   'lesley',
#   'ann',
#   'warren',
#   'ex',
#   'dancer',
#   'get',
#   'divorce',
#   'lose',
#   'home',
#   'pal',
#   'sailor',
#   'howard',
#   'morris',
#   'fume',
#   'teddy',
#   'wilson',
#   'street',
#   'survivor',
#   'bolt',
#   'isn',
#   'not',
#   'reach',
#   'mutual',
#   'agreement',
#   'like',
#   'rich',
#   'fight',
#   'flight',
#   'kill',
#   'kill',
#   'br',
#   'br',
#   'love',
#   'connection',
#   'molly',
#   'bolt',
#   'wasn',
#   'necessary',
#   'plot',
#   'find',
#   'life',
#   'stink',
#   'mel',
#   'brook',
#   'observant',
#   'film',
#   'prior',
#   'comedy',
#   'show',
#   'tender',
#   'compare',
#   'slapstick',
#   'work',
#   'blaze',
#   'saddle',
#   'young',
#   'frankenstein',
#   'spaceballs',
#   'matt',
#   'like',
#   'valuable',
#   'lose',
#   'day',
#   'hand',
#   'make',
#   'stupid',
#   'bet',
#   'like',
#   'rich',
#   'people',
#   'don',
#   'know',
#   'money',
#   'maybe',
#   'should',
#   'homeless',
#   'instead',
#   'like',
#   'monopoly',
#   'money',
#   'br',
#   'br',
#   'maybe',
#   'film',
#   'inspire',
#   'help'],
#  ['airport',
#   'start',
#   'brand',
#   'new',
#   'luxury',
#   'plane',
#   'load',
#   'up',
#   'valuable',
#   'painting',
#   'belong',
#   'rich',
#   'businessman',
#   'philip',
#   'stevens',
#   'james',
#   'stewart',
#   'fly',
#   'bunch',
#   'vip',
#   'estate',
#   'preparation',
#   'open',
#   'public',
#   'museum',
#   'board',
#   'stevens',
#   'daughter',
#   'julie',
#   'kathleen',
#   'quinlan',
#   'son',
#   'luxury',
#   'jetliner',
#   'take',
#   'plan',
#   'but',
#   'mid',
#   'air',
#   'plane',
#   'hello',
#   'jack',
#   'co',
#   'pilot',
#   'chamber',
#   'robert',
#   'foxworth',
#   'accomplice',
#   'banker',
#   'monte',
#   'markham',
#   'wilson',
#   'michael',
#   'pataki',
#   'knock',
#   'passenger',
#   'crow',
#   'sleep',
#   'gas',
#   'plan',
#   'steal',
#   'valuable',
#   'cargo',
#   'land',
#   'disused',
#   'plane',
#   'strip',
#   'isolate',
#   'island',
#   'but',
#   'make',
#   'descent',
#   'chamber',
#   'almost',
#   'hit',
#   'oil',
#   'rig',
#   'ocean',
#   'lose',
#   'control',
#   'plane',
#   'send',
#   'crash',
#   'sea',
#   'sink',
#   'bottom',
#   'right',
#   'bang',
#   'middle',
#   'bermuda',
#   'triangle',
#   'air',
#   'short',
#   'supply',
#   'water',
#   'leak',
#   'fly',
#   'mile',
#   'course',
#   'problem',
#   'mount',
#   'survivor',
#   'await',
#   'help',
#   'time',
#   'fast',
#   'run',
#   'br',
#   'br',
#   'know',
#   'slightly',
#   'different',
#   'tile',
#   'airport',
#   '2',
#   'sequel',
#   'smash',
#   'hit',
#   'disaster',
#   'thriller',
#   'airport',
#   'direct',
#   'jerry',
#   'jameson',
#   'again',
#   'like',
#   'predecessor',
#   'airport',
#   'sort',
#   'forget',
#   'classic',
#   'entertain',
#   'not',
#   'necessarily',
#   'right',
#   'reason',
#   'airport',
#   'film',
#   'see',
#   'far',
#   'actually',
#   'like',
#   'well',
#   'favourite',
#   'plot',
#   'nice',
#   'mid',
#   'air',
#   'hello',
#   'jack',
#   'crash',
#   'didn',
#   'oil',
#   'rig',
#   'sink',
#   'maybe',
#   'maker',
#   'try',
#   'cross',
#   'original',
#   'airport',
#   'popular',
#   'disaster',
#   'flick',
#   'period',
#   'poseidon',
#   'adventure',
#   'submerge',
#   'stay',
#   'end',
#   'stark',
#   'dilemma',
#   'face',
#   'trap',
#   'inside',
#   'suffocate',
#   'air',
#   'run',
#   'drown',
#   'flood',
#   'door',
#   'open',
#   'decent',
#   'idea',
#   'great',
#   'little',
#   'disaster',
#   'flick',
#   'but',
#   'bad',
#   'unsympathetic',
#   'character',
#   'dull',
#   'dialogue',
#   'lethargic',
#   'set',
#   'piece',
#   'real',
#   'lack',
#   'danger',
#   'suspense',
#   'tension',
#   'mean',
#   'miss',
#   'opportunity',
#   'sluggish',
#   'plot',
#   'keep',
#   'entertain',
#   'odd',
#   'minute',
#   'not',
#   'much',
#   'happen',
#   'plane',
#   'sink',
#   'not',
#   'much',
#   'urgency',
#   'think',
#   'should',
#   'navy',
#   'involve',
#   'thing',
#   'don',
#   'pick',
#   'up',
#   'much',
#   'few',
#   'shot',
#   'huge',
#   'ship',
#   'helicopter',
#   'fly',
#   'but',
#   'lack',
#   'george',
#   'kennedy',
#   'jinx',
#   'airline',
#   'worker',
#   'joe',
#   'patroni',
#   'but',
#   'get',
#   'couple',
#   'scene',
#   'barely',
#   'say',
#   'prefer',
#   'look',
#   'worry',
#   'background',
#   'br',
#   'br',
#   'home',
#   'video',
#   'theatrical',
#   'version',
#   'airport',
#   'run',
#   'minute',
#   'tv',
#   'version',
#   'add',
#   'extra',
#   'hour',
#   'footage',
#   'include',
#   'new',
#   'open',
#   'credit',
#   'sequence',
#   'scene',
#   'george',
#   'kennedy',
#   'patroni',
#   'flashback',
#   'flesh',
#   'character',
#   'long',
#   'rescue',
#   'scene',
#   'discovery',
#   'couple',
#   'dead',
#   'body',
#   'include',
#   'navigator',
#   'like',
#   'extra',
#   'footage',
#   'not',
#   'sure',
#   'sit',
#   'near',
#   'hour',
#   'cut',
#   'airport',
#   'expect',
#   'film',
#   'date',
#   'badly',
#   'horrible',
#   'fashion',
#   'interior',
#   'design',
#   'choice',
#   'no',
#   'toy',
#   'plane',
#   'model',
#   'effect',
#   'aren',
#   'great',
#   'airport',
#   'sequel',
#   'take',
#   'pride',
#   'place',
#   'razzie',
#   'award',
#   'hall',
#   'shame',
#   'think',
#   'lot',
#   'wrong',
#   'film',
#   'reckon',
#   'little',
#   'harsh',
#   'action',
#   'scene',
#   'little',
#   'dull',
#   'unfortunately',
#   'pace',
#   'slow',
#   'not',
#   'much',
#   'excitement',
#   'tension',
#   'generate',
#   'shame',
#   'reckon',
#   'pretty',
#   'good',
#   'film',
#   'properly',
#   'br',
#   'br',
#   'production',
#   'value',
#   'alright',
#   'nothing',
#   'spectacular',
#   'act',
#   'isn',
#   'great',
#   'time',
#   'oscar',
#   'winner',
#   'jack',
#   'lemmon',
#   'say',
#   'mistake',
#   'star',
#   'time',
#   'oscar',
#   'winner',
#   'james',
#   'stewart',
#   'look',
#   'old',
#   'frail',
#   'time',
#   'oscar',
#   'winner',
#   'lee',
#   'grant',
#   'look',
#   'drink',
#   'sir',
#   'christopher',
#   'lee',
#   'give',
#   'little',
#   'plenty',
#   'familiar',
#   'face',
#   'look',
#   'too',
#   'br',
#   'br',
#   'airport',
#   'disaster',
#   'orientate',
#   'airport',
#   'film',
#   'far',
#   'like',
#   'idea',
#   'bite',
#   'silly',
#   'production',
#   'bland',
#   'direction',
#   'doesn',
#   'help',
#   'film',
#   'sink',
#   'plane',
#   'shouldn',
#   'bore',
#   'lethargic',
#   'follow',
#   'concorde',
#   'airport'],
#  ['brilliant',
#   'act',
#   'lesley',
#   'ann',
#   'warren',
#   'well',
#   'dramatic',
#   'hobo',
#   'lady',
#   'see',
#   'love',
#   'scene',
#   'clothe',
#   'warehouse',
#   '2',
#   'none',
#   'corn',
#   'face',
#   'classic',
#   'good',
#   'blaze',
#   'saddle',
#   'lawyer',
#   'superb',
#   'accuse',
#   'turncoat',
#   'sell',
#   'boss',
#   'dishonest',
#   'lawyer',
#   'pepto',
#   'bolt',
#   'shrug',
#   'indifferently',
#   'lawyer',
#   'say',
#   'funny',
#   'word',
#   'jeffrey',
#   'tambor',
#   'favorite',
#   'late',
#   'larry',
#   'sander',
#   'fantastic',
#   'too',
#   'mad',
#   'millionaire',
#   'want',
#   'crush',
#   'ghetto',
#   'character',
#   'malevolent',
#   'usual',
#   'hospital',
#   'scene',
#   'scene',
#   'homeless',
#   'invade',
#   'demolition',
#   'site',
#   'time',
#   'classic',
#   'look',
#   'leg',
#   'scene',
#   'big',
#   'digger',
#   'fight',
#   'bleed',
#   'movie',
#   'get',
#   'well',
#   'time']]

# %%
emb_model.wv.similar_by_word(word="good", topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('decent', 0.7074456810951233),
#  ('darn', 0.6548200845718384),
#  ('alright', 0.6462702751159668),
#  ('great', 0.6457749605178833),
#  ('nice', 0.6239773035049438)]

# %%
emb_model.wv.similar_by_word(word="bad", topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('suck', 0.7208997011184692),
#  ('horrible', 0.7207365036010742),
#  ('terrible', 0.714970588684082),
#  ('awful', 0.6812218427658081),
#  ('lame', 0.6796892881393433)]

# %%
emb_model.similar_by_word(word="be", topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('would', 0.9116214513778687),
#  ('have', 0.8634248971939087),
#  ('-PRON-', 0.8267257213592529),
#  ('eventy', 0.7624976634979248),
#  ('s', 0.7046369314193726)]

# %%
emb_model.most_similar(positive=  "bad",topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('suck', 0.7208997011184692),
#  ('horrible', 0.7207365036010742),
#  ('terrible', 0.714970588684082),
#  ('awful', 0.6812218427658081),
#  ('lame', 0.6796892881393433)]

# %%
emb_model.similarity("good","bad")
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.59436196

# %%
emb_model.similarity("good","be")
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.27517337

# %%
emb_model.accuracy
# Out:
# <bound method Word2Vec.accuracy of <gensim.models.word2vec.Word2Vec object at 0x7f2bda621be0>>

# %%
emb_model.similar_by_word(word="school", topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('student', 0.7639281749725342),
#  ('college', 0.7610238790512085),
#  ('class', 0.7575020790100098),
#  ('teacher', 0.7121667861938477),
#  ('schoolers', 0.7093414664268494)]

# %%
emb_model.similar_by_word(word="comedy", topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('satire', 0.6905634999275208),
#  ('slapstick', 0.6813418865203857),
#  ('humor', 0.666489839553833),
#  ('parody', 0.6656045913696289),
#  ('farce', 0.6495898962020874)]

# %%
emb_model.similar_by_word(word="action", topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('suspense', 0.638068675994873),
#  ('thrill', 0.6378527879714966),
#  ('overabundance', 0.57851642370224),
#  ('excitement', 0.5689365863800049),
#  ('gory', 0.565312385559082)]

# %%
emb_model.similar_by_word(word="sad", topn=5)
# Out:
# /home/jibin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# /home/jibin/.local/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('depress', 0.746796727180481),
#  ('cry', 0.7335566282272339),
#  ('happy', 0.6977354884147644),
#  ('touch', 0.664000391960144),
#  ('honestly', 0.6391709446907043)]

# %%
def word2idx(review):
    index_review = []
    for word in review:
        try:
            index_review.append(emb_model.wv.vocab[word].index)
        except: 
             pass
    return torch.tensor(index_review)

# %%
max([len(review) for review in reviews])
# Out:
# 1423

# %%
emb_model.wv.index2word[0]
# Out:
# 'br'

# %%
len(emb_model.wv.index2word)
# Out:
# 28166

# %%
padding_value = len(emb_model.wv.index2word)

# %%
review_lengths = [len(sentence) for sentence in reviews]

# %%
longest_review = max(review_lengths)

# %%
BATCH_SIZE = 128

# %%
import torch

# %%
import torch.nn as nn

# %%
torch.nn.utils.rnn.pad_sequence([torch.tensor([1,2,3]), torch.tensor([3,4])], batch_first=True, padding_value=6)
# Out:
# tensor([[1, 2, 3],
#         [3, 4, 6]])

# %%
emb_model.wv.vectors.shape
# Out:
# (28166, 100)

# %%
weights = torch.FloatTensor(emb_model.wv.vectors)

# %%
weights.shape
# Out:
# torch.Size([28166, 100])

# %%
embedding = nn.Embedding.from_pretrained(weights)

# %%
embedding.weight.requires_grad
# Out:
# False

# %%
index_review = list(map(lambda review: word2idx(review),reviews))

# %%
type(index_review)
# Out:
# list

# %%
longest_review = max([len(review) for review in index_review])

# %%
longest_review
# Out:
# 1400

# %%
class RNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim):
        super().__init__()
        
#         self.embedding = nn.Embedding(input_dim,embedding_dim).from_pretrained(weights)
        self.embedding = nn.Embedding.from_pretrained(weights)
        self.rnn = nn.RNN(embedding_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)
        
        
    def forward(self, x):

        embedded = self.embedding(x)
        
        output, hidden = self.rnn(embedded)
                
        assert torch.equal(output[-1,:,:], hidden.squeeze(0))
        
        return self.fc(hidden.squeeze(0))

# %%
review_lengths = [len(sentence) for sentence in index_review]

# %%
# index_review = torch.nn.utils.rnn.pad_sequence(index_review,batch_first=True)

# %%
review_lengths[:5]
# Out:
# [66, 58, 197, 414, 74]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
from sklearn.model_selection import train_test_split

# %%
labels = [0 if label == 'negative' else 1 for label in labels ]

# %%
X_train, X_test, y_train, y_test = train_test_split(index_review, labels, test_size=0.2)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
len(X_train)
# Out:
# 16000

# %%
# y_train = torch.Tensor(y_train)
# y_val = torch.Tensor(y_val)
# y_test = torch.Tensor(y_test)

# %%
labels[:5]
# Out:
# [1, 0, 1, 0, 1]

# %%
# X_train = torch.nn.utils.rnn.pad_sequence(X_train,batch_first=True)
# X_val = torch.nn.utils.rnn.pad_sequence(X_val,batch_first=True)
# X_test = torch.nn.utils.rnn.pad_sequence(X_test,batch_first=True)

# %%
#torch.stack(X_train)

# %%
len(X_train[0]),len(X_train[1])
# Out:
# (92, 71)

# %%
INPUT_DIM = longest_review
EMBEDDING_DIM = 100
HIDDEN_DIM = 256
OUTPUT_DIM = 1

# %%
model = RNN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)

# %%
import torch.optim as optim

optimizer = optim.SGD(model.parameters(), lr=1e-3)

# %%
criterion = nn.BCEWithLogitsLoss()

# %%
model = model.to(device)
criterion = criterion.to(device)

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum()/len(correct)
    return acc

# %%
def train(model, iterator, optimizer, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch in iterator:
        
        batch1 = {}
        
        
        
        batch1["text"] = batch["text"].t().cuda()
        
        optimizer.zero_grad()
                
        predictions = model(batch1["text"]).squeeze(1)
        
        
        
        loss = criterion(predictions, batch["label"].cuda())
        
        acc = binary_accuracy(predictions, batch["label"].cuda())
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
            batch1 = {}
            batch1["text"] = batch["text"].t().cuda()

            predictions = model(batch1["text"]).squeeze(1)
          
            loss = criterion(predictions, batch["label"].cuda())
            
            acc = binary_accuracy(predictions, batch["label"].cuda())

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
# N_EPOCHS = 5

# for epoch in range(N_EPOCHS):

#     train_loss, train_acc = train(model, train_iterator, optimizer, criterion)
#     valid_loss, valid_acc = evaluate(model, valid_iterator, criterion)
    
#     print(f'| Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:.2f}% |')

# %%
X_train
# Out:
# [tensor([  139,    36,    19,   534,    39,     1,   914,   508,    91,    19,
#           1135,     0,     0,    42,   107,     2,    19,   552,  3013,    57,
#            122,     9,     2,     0,     0,   245,  1806,   979,   835,     1,
#           3013,   526,  5748, 14461,  5644,   147,    84,    92,     2,     0,
#              0,     5,    72,   531,  1357,   140,   158,   742,   432,   275,
#            344,     5,    30,   288,     2,    45,   100,     0,     0,     2,
#            400,  1062,   697,  1054,     1,     6,    60,  3849,  3440,  2076,
#              0,     0,    18,  3013,    71,   119,    35,    68,    82,    37,
#            487,   608,   111,   242,    51,   178,    98,    61,  3013,  1135,
#            295,     2]),
#  tensor([    5,     1,  1247,    53,  1956,  1746,   341,    96,     1,   551,
#              4,   292,    80,  1582,  1450,   402,   950,  3302,    28,    14,
#             69,   101,     1,   322,   160,   608,    22,  6754,    41,     5,
#             28,    22,    68,   223,     5,    22,    23,  6698,   109,   292,
#              4,    41,   753,  1071,  4838,    80,   748, 19554,  1351,  4683,
#            103,    41,   522,   750,    39,  2224,   160,    24,   818,   399,
#            472,    31,   927,    36,    24,   141,     5,   462,   319,   279,
#            243]),
#  tensor([  226,    51,  1129, 26805,  3179,  4344,  6455,  7427, 10710,  7610,
#            658, 12488,  5010,  5464,  1065,  2518,  1975,   179,   301,   304,
#             35,   734,     2,   165, 14884,  1634,  1354,    61,     5,  6875,
#            100,  4192,   644, 26805,   149,    43, 10107,   331,  3363,  2769,
#            452,  1045, 14163,  1691,  5016,   480,  1588,  3560,  5017,   192,
#            945,    62,   438,   430,  6127,   144,    48,    99,    38,     0,
#              0,  1158,    18,   778,  1672,  3423,    82,   554,   313,  1815,
#           3599,   717,   483,   255,   411,   179,    34, 11044,  4965,   261,
#             75,  1271,  1065,   580,    10,    40,    49,   375,  2087,  9160,
#           3575,   235,   326,   435,  5046,   784,  3208,  5652,   682,  4020,
#            949,   178,  2791,  1733,   395, 21071,  3419,   100,   734,   179,
#           2122,  2442,   425,  1815,  2789,   119,    64,    43, 20652,   649,
#            310,  6590,   179,   817, 16607,  2767,  2087,   889,   119,   186,
#           2737, 17502,  3320,   411,   173,  2901,     5,   179,    40,    49,
#            301,  6525,    30,  9569,  2534,   451, 14541,     0,     0,  1129,
#          26805,   386,  2769,  7580,   226,  4151,    13,   978,   979,  9000,
#           6481,  3121,  1080,   331,  3795,   527,   100,   288,   936,  1212,
#           6715,     1,   196, 14008,   350,  1959,  2593, 17557,  3982, 12435,
#           6042,   255,    32]),
#  tensor([  104,   131,     1,   595,     5,   488,    61,    57,    91,   911,
#            363,    67,    32,  1263,   121,     6,  1028,   235,  9301,     0,
#              0,    14,   615,   258,   347,    17,     6,    75,  4091,  4493,
#            884,    27,   284,     9, 23583,   651,    32,   237,     0,     0,
#          26641,    18,   579,    13,    55,    33,   148,  3703,     0,     0,
#            131,   484,     1,   454,   380]),
#  tensor([20484,   305,   132, 15990,     2,  2603,    40,    13,    25,  1523,
#           3625,   558,   351,   170,   326,     5,   129,  3545,    39,  1632,
#          18326,    75,    35,    60,    22,  1721,    43,  1020,  2161,   544,
#           7990,   839,   980,  1159,  1334,  4166,   168,  1159,   349,  2527,
#            303,  1632,    66,  1632,   176,    25,   119,   370,  2192,   170,
#            326,   210,    12, 11398,    91,     5,   544,  7990,   518,     1,
#             50,  1177,   123,     3,   529,   883,   119,   116,     1,   123,
#              7,  1177,     4,   882,     3,  8797,    50,   311,    22,    76,
#             94,   464,     3,  1087,     2,     3,  2418,    94,    21,    60,
#            256,     2,   218,  4134,  1728,    69,     5,     6,  4318,  1257,
#           1532,     0,     0,   947,   800,     0,     0,    13,  7597,  1184,
#              0,     0,   180,  1497,  8978, 11518,    59,  4465, 12729,   660,
#           4465, 12729,  2162,    86,   317,   360,   180,   180]),
#  tensor([ 1743,  2544,   165,    62,  2392,    11,     0,     0,   380,  3424,
#           3567, 14967,  9569,  2454,   183,   112,   686,    33,    17,     6,
#            183,   407,    64,   251,   235,   654,  5487,    12,   611,   116,
#             66,     0,     0,    28,   187,    15,   133,  3270,   344, 14967,
#            654,   111,    14,    35,     3,  2867,  1135,   290,   217,    17,
#          14189,   180,  9031,     0,     0,  1232,     2, 13424,    11,    69,
#            418,    53]),
#  tensor([17237,   544, 13312,   430,   658,    40,     3,    44,   556,   135,
#            475,   283,   225,    25,   251,    38,  1188,   336,    23,    14,
#           2701,   155,   864,  1330,    33,  2511,   153,  3930,  2972,   113,
#           1021,  1676,  4254, 13905,  1330,    21,    10,   475,     0,     0,
#             0,    0,  186,   55,   23, 1695,    1,    3, 2947,   86, 1695, 5500,
#           141,   31,   11,   14,    1,  670, 2765,    0,    0,   70,  136,  124,
#          2125,  209, 6368,  486,   81,   94,    1,  421, 3897, 1527,  256,   78,
#          1295,  172,  488,   34, 5620,   52, 3054, 9498,    4, 3493, 7176,   17,
#           787, 1849,   16,  304,    0,    0,    1,    4,    6,  617,    1,    3,
#           215, 1094, 1111, 2334,   65,   45, 2500,  618,  866,  354]),
#  tensor([ 415,   33,    1,   14,  440,    0,    0,   77,  581, 1594, 1916, 2160,
#           271,    6,  712,   29,  128,    1,   26,  589, 3010, 3458, 1108, 2315,
#           459, 5194,   21, 1164,   24,  426,  126, 2005,    0,    0,  197,   61,
#           232, 1414,  400, 5241,  246,  881,  449,  266, 6636, 2726, 1637, 7760,
#           872,   12,   76,    2,  209,  172,   39,   53,   11,    3,  513,  305,
#           725,   23,    9,    2,   22,    8, 1363,  195,   16,    3,   32,   20,
#            46, 1607,   39,   11,  595,  509, 8102, 1517,    8,   37,  352,  637,
#          1108,    0,    0,  248,  509,   39,  509,   29,  128,  418, 1332,    1,
#            21,   10,  405, 1502, 2232, 1156]),
#  tensor([ 3401,    18,     1,    75,    58,   375,  3401,  3312, 12197,  4769,
#           5356,  1335,  2692,  2915,  1203,  1154,  1335,  3313,  5979,  3616,
#          17120,   666,   110,   105,     5,    86,   505,   618,   774,     2,
#            162,     1,  2590,   154,    33,   182,     8,  3401,     0,     0,
#          12197,  4769,    48,  6480,    57,    59,    98,   777,  1838,  6700,
#             57,  3313,  5979,   176,    10,   548,  1239,    57,  1971,   353,
#            901,    66,    57,  3616, 17120,    60,   400,   327,  1543,  1958,
#          12197, 23358,    48,     5,   322,    57,  7073,   208,   645,    16,
#           2440,  4875,    18,   944, 12197,  4769,    16,     0,     0,    15,
#             33,     1,   311,   887,   796,   458,   398,   249,   149,     1,
#             43,   468,    15,    13,    50,  1490,     1,  1193,  3758,   193,
#            193,   289,  1380,   263,  1082,  2941,    92,    16,  7460,     0,
#              0,   320,     6,  1971,   353,    35,   538,     6,  3401]),
#  tensor([  673,   744,   914,   213,   251,    48,     1,     5,   264,  1084,
#            914,  1217,    13,   120,  1291,  2136,   866,   203,   406,   492,
#            162,   152,    61,  1617,    27,   593,    79,  1617,    27,   788,
#            183, 24691,   115,  1559,   213,   131,  1891,   102,  5727,  1084,
#             61,    68,   593,    79,  1420,   200,    29,  5727,   335,   245,
#            183,   213,  5727,   395,  2788, 20225,  1459,     7,   593,  2254,
#           2608,     2,  1617,   306,   455, 11501,   593,    36,   120,  1492,
#           1181,   116,   593,    30,  1617,  3215,   120,    75,  2136,   152,
#            593,    19,   229,   255,   701,  1377,    19,   672,     1,   191,
#            126,   306,   455,     4,  5203,  3477,   131,   126,    61,    29,
#            152,  3620,   166,   866,     1,   240, 24692,   152,   163,   203,
#            339,  3649,    76,  1533,  2136,   152,  2748,     5,   216,   198,
#             64,   159,   152,   312,   103]),
#  tensor([    1,   628,    50,  1246,   828, 25749,     1,    24,    42,   219,
#            319,  2161,  4760,   614,  2057,    61,   271,   167,  2161, 22861,
#           6890,   388,   302,   980,  9596,   315, 17401,   901,    66,    44,
#            980,  9596,  3745, 17401,  1439,  2848,  1550,  3317,    44,    28,
#             47,  2753,    69,    47,    20,  5430,     3,    12,   118,     1,
#             33,     5,     1,   963,     1,    21,   357,   177,   156,     7,
#            564,   473,  1011]),
#  tensor([    1,     4,   679,   157,    81,   576,   842,   879,    49,  6361,
#            332,   185,   197,    43,   614,   360,    11,    99,     4,    24,
#            273,   643,  1483,    14,   161,   928,  7804,  2443,   543,    16,
#            107,     2,    14, 10588,    22,     6,   682,  3737,  1713,    31,
#             78,     5,    33,     2,   250,   254,     3,    10,   712,     2,
#             56,    11,    19,    53,     0,     0,  1485,    10,     2,   241,
#              0,     0,   606]),
#  tensor([ 765, 3248,  108,    7,   15,   91,  367,  150,  502, 7510, 2167,  220,
#             8,  701,   26, 6225, 1657,  210, 1657,  241,   25,  541,  237, 1802,
#            12,  270]),
#  tensor([   73,    15,  5655,   189,   405,   431,   116,     4,   104,  5655,
#              3,   479,   115,  4516,   541,   159,   192,   141,   177,     7,
#            116,     2,   396,   237, 12389,   426,    89,     1,    12,   221,
#              3,    18,    11,  1393,    64,   141,  2901,   313,   850,    51,
#           5029,   220,  1256,    23,  8673,  1794,   651,   636,    23,   293,
#            285,     2,   213,     2,   192,   141,   291,    26,    29,   271,
#            773,   232,  2177,   603,   377,  8276,  1546,   177,     7,   307,
#             69,    25,  2155, 12969,   597,    47,     1,     7,    15,    47,
#              2,   450,     8,    76,   540,  1503,   115,    28,   112,   508,
#           4473,  2182,   319,  1693,  1275,   268]),
#  tensor([   13,     1,  1091,   619,  2684,  2318,   334,    91,   383,  1359,
#             46,    36,   130,    29,   383,     1,   310,    45,    41,  5152,
#            679,   359,   305,   120,   566,     3,    47,   171, 10134,    21,
#              1,    70,     4,   222,     1,  3757,   619,   553,  2318,     3,
#             85,   177,     7,   470,   528,   743,    46,  3232,  1240,   491,
#            141,     2,     3,   364,   141,   306,     4,   470,  9019,     1,
#            470,    28,    45,   103,   992,   434,     1,     3,   692,     4,
#              9,  3995,   681,    70,    66]),
#  tensor([   18,  1784,  3905,  2871,    59,   373,    93,  1048,    90,  2421,
#            267,   778,  5488,  2871,    30,  5448,  5482,  1241,   226,   135,
#           5488,   213,   497,    90,  3905,   557,    71,   698,    62,    18,
#           3918,   226, 17946,  2871,  5488,   267,   499,    36,    24,    44,
#           5473,  1988,   491,     6,  1047,  2567,  1389,  5342,   778,  3307,
#            178,  5370, 16826, 26317,  3905,  2871,  4995,   109,     2,  1983,
#             53, 12127,  3905,  2871]),
#  tensor([   31,     1,   546,    18, 10327,     1,  1356,    17,   951,    31,
#            117,     1,    18,   265,   667,   117,     0,     0,    11,    18,
#             18,    45,  1377, 12685,   764,   755, 10327,  5062,    18,     1,
#              6,  1377,  1014,    33,    67,     6, 23216,   785,   859,   879,
#             10,   135,  5062,   741,   106,    65,     1,    20,    71,     0,
#              0,     3,   320,   951,     1,   326,  2397,   152,   159]),
#  tensor([  755,  8081,   471,  8644,     6, 13379,   972,     4,  1173,    82,
#              2,    59,   402,  2831, 11858,  6208,    71,    63,   748,     0,
#              0, 24480,    59,    35, 24481,  4347,     0,     0,  1447,    18,
#            454,  6960,  1461,  3568,  4079,    30,  4990,  1536,  7461,  3568,
#            201,  1477,     0,     0,  7614,    17,     6,   107,  1656,     0,
#              0,   283,    50,   498,    12,  1446,  1925,     0,     0,     4,
#            748,    81,   495,    84,  1871,   686,   521,   748,   356,   495,
#           2439,    40,     7,   107,    19]),
#  tensor([   75,    13,    78,     1,   533,  3830,   861,  9690,     1,    87,
#            167,   456,     9,   266,   449,    26,   146,  1307,    93,   168,
#           8472,  6361,   786,   132,   131,   236,   412,  1898, 26024,  1952,
#            146,  1713,   891,   131,    84,   412,  1081,    48,  5371,   189,
#            565,   219,   533,  3325,   146,    38, 11899,  4105,   131,  6361,
#            717,   751,  2292,  6834,   628,   116,     3,  5693,   164,    94,
#             21,    26,    71,   132,   131,   159,   790,  1300,   174,  1117,
#             38,   156,   482,     1,   809,   623,   202,    34,     5,    72,
#              1,     2, 14371,  1751,  3039,  4324,    39,   146,  1356,   305,
#           2847,    56,    43,    92,   214,     6,   108,    21,    44,    13,
#              2,   201,    67,   257,   190,    48,    43,   190,    91,     5]),
#  tensor([10016,     5,    22,  1578,    76,    97,    13,   742,     1,    28,
#              5,     4,  2520,   116,    21,   482,    58,  7118,     8,    27,
#             45,   355,     1,     0,     0,     1,  2219,  2436,  2547,    43,
#           2069,   232,   154,    14,   205,  1649,    55,    13,    50,    40,
#             77,   576,  1187,   595,     1,    48,  2674,     0,     0,    39,
#            855,   908,    41,     5,     3,  1890,  2674,   655,   434,    71,
#           1041,    22,     4]),
#  tensor([   22,     3,    48,   651,   125,   161,  2499,   137,   136,    78,
#            264,    91,   482,    67,    14,    21,    10,    45,  1155,     0,
#              0,    39,  1778,   976,  1731,   119,   494,  9848,   834,    83,
#            577,   329,  4180,  3320,     5,  1731,    28,    22,   247,    67,
#            725,    19,   436,  3384,     0,     0,   227,   668,    11,   479,
#            133,  2377,   789,   354,    45,   349,  1248,  1702,     0,     0,
#           1084,   683,  9630,    71,   162,     1,    87,    11,     6,    46,
#           1355,  1233,    94,   458,    25,   735,    45,     6,   304,   845,
#             39,    76,    92,   277,    71,  1177,     2,     6,  1507,   169,
#             60,    19,     7,  1471,     8,   288,   521,  1202,   826,  1869,
#             88,  1233,   586,   277,     3,   307,    12, 11398,   762,   228,
#           2813,   586,   259,  1731,   153,    88,     4,    48,   431,   326,
#              0,     0,   585,  1356,   252,   165,     3,   383,    29, 10491,
#            398,   668,    11,   130,   107,  3325,   127,    31]),
#  tensor([   31,   903,    14,   172,   476,  1512,  9004,    64,     2,  3820,
#            149,    31,   910,   341, 10794,   149,  1838,    31,  1648,    40,
#            295,   313,    76,  1713,   204,    10,    83,    31,   903,    18,
#             33,     2,    97,     4,   806,   155,   850,    46,   129,   359,
#           9887,     3,  5129, 15085,    64,  1095,   516,    12,   288,   272,
#           1660,  1231,  1752,   341,   619,   909,   520,   591,   357,  9004,
#             44,    37,    11,    85,   766, 11130,     3,   182,  7232,   133,
#             56,   206,  1383,  1483,   456,   485,   361,     8,   275,   245,
#           1806,   466,  1233,   354,  6919,  9626,  2532,  1470,   434,   126,
#             21,    10,    11,    35,  1337,   798,    33,   256,    63,    43,
#           2870,  1737,     0,     0,    64,   408,    57,  1441,  2296,     6,
#             14,   321,    51,   526,  1670,  1866,  3094,  3210,    10,  1838,
#            247,    90,   160,  5421,     8,     6,  1204,  6032,   456,   125,
#          10163,   344,     3,  4562,    35,  2755,    83,    35,    12,  3630,
#            103,   354,  4126,   295,  4131,  1866,   129,  2296,   685,  1507,
#            695,    31,  1512,  9004,    50,   793,  2296,    30,  2348,  1047,
#           8204,   173,   113,    95,  1191,    50,    86,    83,  2187,  1037,
#            133,  2124,    43,   439, 13610,    77,   116,   305,   202,    94,
#             81,   452,   150,  2389,    35,    46,    10, 12444,   201,    31,
#             46,   204,    10,   432,    94,   516,   319,   897,  1306,  3531,
#            133,   292,  2674,   792,  9766,   100,    25,    43, 19028, 13399,
#           2075,     4,  3452,   202,     0,     0,  3820,     4,  1047,  8204,
#           2348,   100,    35,  1277,  2112,    35,  1231,  1031,  7078,  2223,
#          22125, 13396,  2112,   103,    19,   135,    43,    49,   912,  3220,
#           1047,    30,   737,   386,    28,  5099,  2112,   155,  8448,    46,
#            207,    43,    12,   111,    13,  1047,   380,    81,    43,  3158,
#           1217,    45,    40,  6722,   380,    49,   111,    12,   336,    19,
#            207,   195,   100,  5099,     8,    42,  8823,   912,    81,   853,
#           2296,    60,   158,   235,   173,    35,    42,   456,   395,   229,
#            333,    40, 10704,   955,    63,   110,   204,    10,  2830,   520,
#           1174,  2584,    10,  1304, 16630,   262,     0,     0,   322,    61,
#            291,   148,   135,    10,   785,   119, 10597, 10954,   933,    44,
#            282,   932,     2,    30,   901,  1978,   173,  1463,     3,   339,
#             16,  1141,  5099,    59,   154,   163,  9203,  4400,   106,   390,
#           2914,     3,     1,   236,    87,    37,  2347,   272,    61,   245,
#           1134,   905,   242,    51,  1512,  9004,    68,  2296,    49,    15,
#            111,  9135,  6482,    45,   103,   204,   357,    41,   283,     2,
#              3,     4,    20,   184, 11719,  7965,    18,   282,    30,    31,
#           2124,  2272,    46,    43,  1354,    68,   442,  1716,     3,    21,
#             10,  7742,   553,    32,     0,     0,  9004,  1425,    15,   698,
#              8,  1051,    13,    79,     7,   311,   114,  2931,  4900,   297,
#              8, 11624,   664,   377,   110,    29,   706,    11,   163,    44,
#             50,   482,    27,  1816,    10,  4829,  1201,  3619,   869,   117,
#            585,  2479,     4,   119,  1752,    18,   160,  6234,   224,  9004,
#             45,   103,   160,  3620,  1400,   622,    21,    28,    22,     3,
#            335,   465,  3820,     2,    31,   864,    47,  1042,  4348,   256,
#           1737,   456,    82,    83,   118,   702,   171]),
#  tensor([  870,  2581,  2058,   785,  1043,  7740,   502, 16507,   353,  2341,
#           1657,    83,  3381, 27426,   121,   409,    83,   409,   785, 16911,
#              0,     0,    14,    90,    47,   288,     5,    10,    11,   349,
#           4714,   241,   592,  6316, 17067,    96,   229,  1518,  2384,     6,
#            149,  3776,    45,     0,     0,    65,   161,     5,  2946,   282,
#            210,    22,   111,     3, 10886, 14796,   106,  2043,  2788,   208,
#           1507,  6901,   452,   276,    29,   478,  4636,  1405,   114,  3677,
#           1344, 18701,  2658,   276,   904,    51,  3546,  1001,   259,     6,
#              1,     8,  1908,  1147,   461,    63, 12334,   154,    11,    28,
#             22,    84,   971, 16096,   904,    38,     0,     0,   843,     1,
#           5465,   355,    53,   154,    76,   196,    58,    27,    63,   490,
#            149,    55,  6591,   325,  1058,   740,   432,  4052,    27,    23,
#              0,     0,   294,     1, 18089,     3,    18,   339,   297,   961,
#           1210]),
#  tensor([  925,   557,   777,   104,   579,    73,   111,    15,   655,  1950,
#              4,    18,   129,   169,   167,    61,  8820,  2814,  5357,   451,
#          14573,  3152,  2985,  2172, 10064,  1647,  6293,   336,  2820, 10349,
#             22,  1851,    79,   108,    19,   549,   102,  1596,   111,    26,
#           8278,   551,   606,   157,   305,   228,     8,  3143,   131,   338,
#           3655,   693,   767,    25,    54,   424,  1656,    54,   597,   226,
#             41,     1,    83,    67,   725,  1316,    72,   111,  3872,   155,
#             53,  5410,   424,  7494,    21,     5,   551,    20,     0,     0,
#            377,  1851,   424,  1536,  1205,    59,  1851,   424,  1303,   663,
#           2686,    50,   564,     5,    52,    32,  4138,  6437,     7,    61,
#             42,    71,  9540,   625,    19,   102,  9276,    71,    41,     4,
#             27,  1199,     0,     0,    21,  5619,  1950,   189,   111,  2492,
#             32,   131,   132,   351,     4,    17,   665,  1365]),
#  tensor([10058,    24,   719,   716,    89,     1,     9,    13,    24,   373,
#              3,   328,     9,    55,  5025,   840,     1,    22,     4,   145,
#             19,   470,   769,     1,    12,    21,   327,   171,  2280,  4474,
#            285,  2563,   171,   300,   335,   525,    98,   110,    22,     3,
#              6, 13963,  3159,   265,    14,    53,    94,    60,    41,   396,
#             57,    48,   105,    28,    22,   265,   541,   169,  5369,  3508,
#           8427,   833,  1110,    50,   225,   935,   387,     7,   315,  2582,
#           6137,  9914,  1421,    48, 12767,   785,   225,    28,  1330,    26,
#             32,  3613,    23,    28,    22,    32,    14,  2217,   647,  5550,
#            791,   505,     3,    22,   536,  3613,  8641,   596,  3613,  2022,
#            343,  3098,   225,    22,  3508,  1168,    31,   382,   317,   109,
#          11530,     4,   177,   185,    43,     9,    15,    14,    47,    20,
#            561,    27,   332,   185,    15]),
#  tensor([ 3053,  4882,   372,  2976,   129,   913,    27,    46,    54,     3,
#           1613, 25427,   268,   551,   145,    32,     4,   807,  1723,   182,
#             42,  6948,    46,   698,     3,  1056,    58,  2391,   271,  1660,
#             24,    66,    17,     6,   590,  2804,   415,     5,   590,  2804,
#             46,   521,   590,  2804,    46,  6595,  1465,   540,    60,    38,
#           1725,   161,     3,     4,   540,    60,   547,  2875,  4221,     5,
#              9,    46,   452,   698,  4351,   269,  2265,    37,    42,  6948,
#             18,    89,   407, 11035,     2,   742,  2445,    29,  5987,     3,
#             47,   172,    66,   375,   559,    27,    36,    19, 15077,  7623,
#           1473,     5,    61,   570,   111,    46,     2,   415,  8315,   221,
#             12,    94,   317,     5,    20,  2232,  1156,   152,   474,     3,
#           3129,     1,   371,  3055,    26,  2232,   152]),
#  tensor([18434,    47,     2,    13,    40,   575,     2,   577,   427,    20,
#            230,     2,    17,     6,     6,   165,     2,   624,  5576,  5211,
#            457,   179,    37,    18,     2,   449,     5,     3,   266,  3311,
#             12,   888, 12392,   466,     2,  5679,  2820,  4881,  6452,  1448,
#            141,     2,     2,    46,    36,   130,  1531,  4477,  1529,  9083,
#            119,    41,   572,  1345,     2,     6,  3118,   472,     2, 11381,
#            343,   511,    68,  7075,    51,  6261,  2180,    16,    56,     2,
#           1747,   344,   990,     4,   374,     1,    16,     3,    50,   118,
#           2524,  2773,   491,     8,   768,   245,   302,   388,   419,    10,
#            882,  1248,    23,    33,   558,   286,   285,    46,  1747,   810,
#            420,   119,   189,   233,     2,  1886,    30,    21,  2816,  1667,
#            363,  1305,   461,   223,    54,    33,     2,     2,     4,    27,
#            964,    12,   270,     2,   565,  1026,   132,   403,   115,    37,
#           1624,    24,   116,    47,    42,     5,  1374,     2,   454,  4088,
#            348,     2,   204,   230,   940,   316,     2,  6333,  8765,  1667,
#            286,   165,  2201,   117,   237,    65,  2750,  3254]),
#  tensor([13914,   107,     1,     6,   380,     3,   167,  1103,    78,   122,
#            197,    91,     5,   108,   320,  1815,  7589,  1285,  8895,    64,
#            387,    30,   489,  4189,  1448,   235,    10,   173,  9396,  4699,
#            111,  1860,  6058,   347,   395,    10,    16,   235,    82,  4189,
#           8918,     5,   108,     5,   777,   594,  2178,  4699,   294,   116,
#            411,  8895,     3,     2,    25,  3610,   253,   884,    16,    85,
#            232,   144,  4189,  4699,    42,    82,   333,   942,   255,    97,
# ...
#          12526,   133,   639,  3520,   381,     2,    20,   181]),
#  tensor([  501,  1071,  1200,   656,  1777,  6788,  1541,     6,  1272,   830,
#           4528, 15985,  3714,    24,    66, 12541,  4705,  1877,  6788,     3,
#           7830,    33,   135,  2152,    20,  1279,     4,     6,    83,    13,
#             64,    20,    83,    13,  4943,  2738,   250,   116,  1234,   847,
#            384,    19,    15, 13572,  4487,   305,   361,  9412,  7527,  1343,
#           2597,  1670,  1102,  6143,   772,  4389,   675,    32,    10,   199,
#             36,     5,    33,   167, 19405,  6375,  2597,  1098,  1929,  7295,
#            473,  1011]),
#  tensor([ 613,  102, 2962,  631,  416,  630,  142,  185, 1891,    1,  165,  608,
#          5556,   89,   51,  294,    9,  106, 6219,    5,  142, 2094,  424,    3,
#           620, 2173, 3978,  325, 7372,  393,  424,   55,   15,    0,    0,  183,
#           472,   20,  424,   78,    5,   11,  424,  978,  193,  722,   62,  200,
#          3289, 5011,  405,  736, 1468,  142,  174,    6,    5,   47,   33,    9,
#           131,   40,  142,  532,   19,   15,  171,  424,   85,   40,    3,    4,
#           319, 2214]),
#  tensor([ 156,   43,  106,  357,    1, 4237, 1239, 2879,    7, 4327,  177, 1352,
#           349,  918,  252,  186,  631,  141,  174,    3,  295,    7,  156,  129,
#           332,  155,  128,  280, 8107, 1148,  411, 1243,  210,   43,  607,    3,
#             1,  736,  177,    7,  156,    9, 4094, 1764,   12,   56, 1343,   94,
#           919, 1468,  423,    3,   29,  371,  548,  468, 7326,   19,    1,    5,
#           512, 1173, 1116,  636,   73]),
#  tensor([   44,    13,  1498,     1,    13, 20317,    14,   115,   335,   310,
#           1498,    40,    49,   477,  7759,     4,   521,  1498,    17,   187,
#             37,  2768,  2762,  1498,    44,    48,  1650, 14129,  2118,   187,
#           1498,  5523,  1537,  3117, 16520, 16520,     0,     0,   317,     5,
#             19,   999,   407,   724,  1819, 18752,    66,  4152,   537,     5,
#             66,   617,  4500,   551,    69,    24,   186,     3,  1065,    69,
#              5,     0,     0,   127,     4,    15,     1,   839,  1498]),
#  tensor([ 1039,    88,   136,  4190,   722,  1533,   576,    73,     0,     0,
#            353,   475,   234,    21,  2057,   312,  4190,    27,   257,   895,
#             26,    15,     6,  4190,   722,  4190,   722,   404,  2562,   168,
#            475,  4497,   588,    22,   895,  1046,   123,  1590,  4190,   722,
#            629,  5624,     0,     0,   112,   982, 10466,   188,    43,    72,
#            109,  1748,    14,   254,  2079,  3452,   196,   237,   335,  9814,
#           9812,  1237,  1556,  1287,   160,   469,   148,    36,     5,     1,
#            635,    20,  2582,   259,    24,   174,     0,     0, 13683, 14480,
#             30,   243,    68,   105,   519,    70,    48,    16, 10820,     6,
#          14371,   374,   786,   654,  2519,   800,  5465,  3978,    12,  1907,
#              3,   759,   129,   112,    19,   282,   455,  1339,   278,  1902,
#              3,  4005,  3385,  9823, 12863,   387,   415,    14,   306,   256,
#              1,  1680,    39,   157,  1546, 10179,   165,   194,   277,  3284,
#           3095,  5178,  7754,  2093,  1109,  2627,    31,    16,  4594,   375,
#            489,   233,    38,   176,   555,  1721,   697,   120,    36, 15172,
#            229,    10,  1922,  2323,  4895,     0,     0,    14,  1485,  7855,
#           5345,     1,    10,  1388,  2781,  2846,    34,  9032,  2393,   967,
#            731,   113,  3596,  7469,   576,     4, 13739,   619,   333,  2300,
#           1726,   309,     3,  2150,  1427,  4239,  5393,  6227,   970,   402,
#           2176,  1746,  2124,   231,   722,   194,   206,  9552,   273, 15915,
#            222,  9874,   621,   586,    88,  1698,    69,   239,     1,   644,
#           1135,  6437,  7440,   521,   506,    42,   248,   106,  4465,   620,
#             32,    10,  2418,  1176,    39,    96,  1137,    21,     0,     0,
#            121,  2208,   370,  1807,     2,   288,   860,  2638,   112,  2283,
#            846,   630,   104,  5214,   249,   286,   314,    60,   947,  3473,
#             58,   194,   309,  1117,  2336,  9346,   505,    42,  5216,   285,
#            681,   914,   361,    10,  1931,  6246,     9,    49,  1555,   576,
#             46,   767,   814,  2093,   306,    89,   361,     7,    28,   634,
#            641,  3299]),
#  tensor([   75,   178,  6289,  1869,  1794,   324,  5851,   428,  1501,   727,
#            417,   201,  8063,    34,    38,    31, 11743,   641,   813,     7,
#           3942,  3329,     4,  6319,   647,  3329,   993, 14173,   804,    13,
#            575,   337,     2,   517,   202,     5,     5,    40,   545,   193,
#           1739,  1564,    40,     6,  6289,  5612,  7656,  1935,    17,   925,
#            567,   217,   742,  2733,  2801,  4011,  2609,   231,   963,   902,
#           2121,    10,    45,     5,    26,  2144,  1739,   291,   603,   188,
#            180,  5444, 15615,    31,  1392,   571]),
#  tensor([ 1625,     7,   574,     2, 14375,   248,  4231,     0,     0, 13783,
#           6477,  1705,   856,    46,    34,    27,   305,   235,  3215,  3165,
#             50,  2135,   532,  1705,     3,     6,   989,   514,  5502,   187,
#           5570,   795,   721,   340, 19635,    30,   737,     0,     0,  5818,
#           8281,   641,   115,   780,    62,  3749,    38,  6743,  4795,  2470,
#            265,    46,    45,   607,  3655,   696,  1859, 11429,     0,     0,
#          10555,    75,   289,    80,    46,    34,    46,   547,   535,   828,
#             34,   382,  1510,  2526,    26,   238,  3336,     0,     0,     2,
#            328,  2511,     6,    33,   328,  2511,    23,  1418,    32,    30,
#              0,     0,   136,   279,    12,   315,   193,     8,     3,   315,
#            289,  3165, 13783,   167,   342,   315,    46,    34,    27,   265,
#            306, 12105,   812,   640,   437, 12619,    73,    98,    95,    67,
#             96,    42,  3894,     0,     0,  1442,  2553, 14531,  4517,  1307,
#            193,    35,  1442,  2553,   477,  2016, 14531,  4517,   342,   668,
#           2573,    59,    12,  4732,  3220,   985,   213,     4,     6,   289,
#             23,    19,  1307,     6,  3165,     3,     4,   379,  3165,   759,
#            320,  6414,   607,    37,  4133,     3,   193,   402,     6,  3165,
#             12,     0,     0,    23,    59,   289,    24,     4,   163,    24,
#            289,     8,  3165,   412,   163,    56,    43, 10555,     5,    80,
#           1064,  5818,  8281,  3220,     5,    66, 13783,     5,    66,  4358,
#              0,     0,  5818,  8281,  1442,  2553, 14531,   462,   714,     8,
#           1307, 21677,  1489, 11560,   412,  2067,  1838, 13783,  4183,   547,
#           2067,  1838,     5,     0,     0,     5,     1,     5,   108,     6,
#              1,   328,  2511,    18,   211,  2530,    25,     0,     0,    28,
#             14,  2553, 14531, 18857,   657,  3165]),
#  tensor([   34,  1277, 23127,   264,  1527,   754,   966,   651,   159,  1794,
#           1289, 22869, 11548,   924,   214,  5336,   422,  3681,  6751,  6528,
#           1180,   956,  5235,     1,   186, 16091,  4437,  1149,   698,  1345,
#          11697,   354,   287,     1,    59,  1811,   933,  1912,   333, 11760,
#             75,    18, 23452,  3720,  1811,   933,  2689,   407,  1811,    95,
#           3897,  1811,   933,    44,  2689, 11760,    75,  4532,  1811,   933,
#           1952,   645,  1912,  1811,   933,   266, 20884,    95,  1912,    50,
#            118]),
#  tensor([ 9154,     2,   404,   567,   894,    11,    51,   506,  5141,   451,
#          15862,  2415,  2313,   674, 15864,  1637,  2297,  2548,  1603,   498,
#             62,   314,     4,  2072,  2261,  5900,   555,  5246,  8507,  9625,
#           4567,     3,   404,   561,     2,    98,   798,    78,  4101,   908,
#           2967,   203,     0,     0,     6,  8507,  9625,  4567,   404,   567,
#            894,  8320,    49,     7,   734,  4920,   596,    33,     2,   227,
#           5086,  1829,  1331,   164,   277,     5,  2830,    16,    84,  8324,
#           1829,  2344,   784,   404, 25374,  5900,   322,    61,    10,   855,
#           2249,     8,    41,   574,   263,   217,  1982,    38,   202,     0,
#              0,   103,   248,    82,     6,  8507,  9625,  4567,   404,   567,
#            894,    60,   129,   625,    27,    70,     5,    11,     3,     6,
#           4567,   404,   343,  9521,  1302,   734,  1043,   329,   646,    43,
#            934,    22,  2967, 25374,     7,   386, 10150,   806,  8507,  9625,
#           4567,     3,    78,  6587,   362,  4711,  1765,   555,  1641,   451,
#          15862,   404,   567,   894, 10235,   114,  2130,  2967,     0,     0,
#           1765, 15862,   737,   554,  2104, 15032,   934,  2510,  1765,    48,
#           5173,   561,  2921,  2786,  3353,   163,    43,    57,    35,  1740,
#            236,  3010,     9,  4711,  1765,    92,    17,   115, 14684,     5,
#              7,   404,   567,   894,   451, 15862,  3117,    43,     2,   326,
#           1719,    33,    10,   172,  6509,    82,     0,     0]),
#  tensor([    1,    59, 12116, 15860,   427,   306,  2965,     0,     0,   513,
#             11,   242,    28,   319,   678,   284,   187,   434,    23,   109,
#            122,     9,  1123,  1926,   359,  4082,   338,     4,    17,   530,
#              0,     0,     1,   240,  1817,    27,     1,    98,   207,   281,
#            121,  1226,   182,    11,  1226,   615,   390,    46,    70,    23,
#            337,     7,    96,  1822, 17282,   378,   236,  1113,   369,     0,
#              0,     1,   306,   749,     9,   407,     0,     0,    20,   409,
#           2104,   632,  2711,  3725,   444,  3211,   444,   444,  1054,   248,
#           2505,     1,   630,   285,    12,   630,   797,  5353,     1,     0,
#              0,    26,   630,    11,    33,  2590,  1319,   759,   109,   188,
#            243,     1,    23,   317,   109,   630,     4, 10176,   243,     4,
#            444,   193,    90,    49, 19644,    81,   249,   682,  8808,    19,
#             53,  1027,     6,   300, 13817,   444,   261,  4458,     1,   421,
#             54,     0,     0,     1,   356,   109,   630,  8051,    35,  1265,
#            243,   327,    28,   855,     8,     1,   808,   630,  2321,   303,
#            116,   808,     0,     0,     1, 14409,     4,   444,   303,   370,
#             42,   444,     0,     0]),
#  tensor([  294,  3676,  5228,     2,     0,     0,  2000,   444, 13856, 13857,
#           8562,    64,   203,   485,   203,   485,   303,  2000,   444,   146,
#              0,     0,  5064,    33,   623,    44,   199, 11971,     0,     0,
#              3,    60,    96,   112,     5,     2,   519,   354,  2000,   444,
#             70,  3676,  5228,  1418,    22,    11,  2000,   444,   313,    32,
#              0,     0,   407,   379,     9,    14,   317,   360,   606,   379,
#           1177,    19,  1039,   551,    96,  5228,    37,    10,  1104,    71,
#            245,  3676, 23217,    22,  3676,    25,    71,     3,    60,   293,
#            474,  5151, 13856, 13857,  5950,     4,    94,     0,     0,   447,
#            692,  4100,   268,   462,   145,     2,  5228,    50,  3230,   498,
#              3,  4100,   268,   144,     5,    52,  1103,   645, 10826,     0,
#              0,   391,   308,   384,    18,  1561,   208,    41,   972,   391,
#             99,  1629,  3976,  2974,   418,  1588,     0,     0,   117,    18,
#            267,   367,   924,   491,  1363,   414,   149,  1014,  6403, 19903,
#           1071,  6351,   158,   667,   286,  1228,   616,   226,    38,  3612,
#           5948,  1071,  2939,  6478,    85,  2326,   235,   973,  2315,  3317,
#            613,     2,     0,     0,     2,   720,  2210,    33,   462,     1,
#           2288,  3428,     4,  2240,  2926,  4435,   232,  4044,    60,    46,
#           9037,    24,     5,   140,   107,   125,     1,   221,   127, 11432,
#           2903,  2556,   852,  2742,   699,   396,   212,     4,  1650,   191,
#            126,   233,    38,   403,   217,  1982,   114,    15,     1,    12,
#            143,  1305,  3099,   371,     0,     0,     4,   714,   146,   224,
#             16,   263,   667,   428,  5851,   417,   224,    30,  2773,  1095,
#             16,    31,    53,    16,   153,   446,    16,   378,   224,    91,
#            606,  1613,  3229,    33,  2885, 11933,    88,   632,     6,  1804,
#             16,  1100,  1975,   197,  1646,  1871,   126,     0,     0,    61,
#            371,   292,   227,  4591,   375,  5777,  5430, 14476,  2939,  2481,
#           9053,  1540, 20469,   304,    98,   447]),
#  ...]

# %%
batch_size = 128 

def iterator_func(X,y):
    
    permutation = torch.randperm(X.size()[0])
    iterator = []
    for i in range(0,X.size()[0], batch_size):
        indices = permutation[i:i+batch_size]
        batch = {}
        batch['text'] = X_train[indices]
        batch["lengths"] = [len(review) for review in batch["text"]]
        batch['label'] = y_train[indices]
        
        #sorted
        batch["text"],batch["label"] = zip(*sorted(zip(batch["text"],batch["label"]),key = len(x[0]),reverse=True))
        
        batch["text"] = torch.Tensor(batch["text"])
        batch["label"] = torch.Tensor(batch["label"])
        batch["text"] = torch.nn.utils.rnn.pad_sequence(batch["text"],batch_first=True,padding_value=padding_value)
        
        
        
        iterator.append(batch)
    return iterator
        
train_iterator = iterator_func(X_train,y_train)
valid_iterator = iterator_func(X_val,y_val)
test_iterator = iterator_func(X_test,y_test)

# %%
len(valid_iterator)
# Out:
# 32

# %%
model
# Out:
# RNN(
#   (embedding): Embedding(28166, 100)
#   (rnn): RNN(100, 256)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
N_EPOCHS = 5

for epoch in range(N_EPOCHS):

    train_loss, train_acc = train(model, train_iterator, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion)
    
    print(f'| Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:.2f}% |')
# Out:
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# | Epoch: 01 | Train Loss: 0.278 | Train Acc: 99.20% | Val. Loss: 0.115 | Val. Acc: 100.00% |
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])
# orignal shape of batch text:
# torch.Size([128, 862])
# shape of prediction:
# torch.Size([128])
# orignal shape of label:
# torch.Size([128])

# %%
test_loss, test_acc = evaluate(model, test_iterator, criterion)

print(f'| Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}% |')

# %%
a = [["a","b"],["f","s","s","g","s"],["a","b","c","d"],["a","s","d"]]
b = [0,1,0,0]

# %%
f,g = zip(*sorted(zip(a,b), key=lambda x: len(x[0]),reverse=True))

# %%
f
# Out:
# (['f', 's', 's', 'g', 's'], ['a', 'b', 'c', 'd'], ['a', 's', 'd'], ['a', 'b'])
